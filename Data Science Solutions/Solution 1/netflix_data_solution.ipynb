# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # About the dataset
# ### Netflix is a popular streaming service that offers a vast catalog of movies, TV shows, and original contents. This dataset is a cleaned version of the original version which can be found here. The data consist of contents added to Netflix from 2008 to 2021. The oldest content is as old as 1925 and the newest as 2021. This dataset will be cleaned with PostgreSQL and visualized with Tableau. The purpose of this dataset is to test my data cleaning and visualization skills. The cleaned data can be found below and the Tableau dashboard can be found here .

# %%
df=pd.read_csv('netflix1.csv')

# %%
df.size
# Out:
# 79110

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV

# %%
df.sample(5)
# Out:
#      show_id     type                 title         director         country  \
# 7157   s2191  TV Show  The Umbrella Academy        Not Given   United States
# 1937   s2372    Movie             Lola Igna  Eduardo Roy Jr.     Philippines
# 5862   s7989    Movie              Sex Doll  Sylvie Verheyde  United Kingdom
# 4198   s5890    Movie               Results  Andrew Bujalski   United States
# 5391   s7385    Movie        Mahjong Heroes     Li Pei-Chuan       Hong Kong
#
#       date_added  release_year rating   duration  \
# 7157   7/31/2020          2020  TV-14  2 Seasons
# 1937   6/18/2020          2019  TV-14    114 min
# 5862   7/10/2017          2016     UR    103 min
# 4198  10/22/2015          2015      R    105 min
# 5391   8/16/2018          1981  TV-PG     92 min
#
#                                               listed_in
# 7157  TV Action & Adventure, TV Mysteries, TV Sci-Fi...
# 1937                     Comedies, International Movies
# 5862      Dramas, International Movies, Romantic Movies
# 4198                       Comedies, Independent Movies
# 5391                     Comedies, International Movies

# %% [markdown]
# ### DataSet description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# ## Tasks We Are gonna do in Data Cleaning process are
# ### 1. Treating the nulls
# ### 2. Treating the duplicates
# ### 3. Populate the missing values
# ### 4. Drop Uneeded Columns

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.drop(columns='rating',inplace=True)

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year  duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# ## Renaming of the columns

# %%
new_columns=[]
for i in df.columns:
    new_columns.append(i.capitalize())

# %%
print(new_columns)
# Out:
# ['Show_id', 'Type', 'Title', 'Director', 'Country', 'Date_added', 'Release_year', 'Duration', 'Listed_in']

# %%
df.columns=new_columns

# %%
df.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# ### Handelling duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Handelling NA Values

# %%
df.isna().sum()
# Out:
# Show_id         0
# Type            0
# Title           0
# Director        0
# Country         0
# Date_added      0
# Release_year    0
# Duration        0
# Listed_in       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
df['Show_id']
# Out:
# 0          s1
# 1          s3
# 2          s6
# 3         s14
# 4          s8
#         ...
# 8785    s8797
# 8786    s8798
# 8787    s8801
# 8788    s8784
# 8789    s8786
# Name: Show_id, Length: 8790, dtype: object

# %%
df['Show_id']=df['Show_id'].apply(lambda x:x.split('s')[1])

# %%
df.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0       1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1       3  TV Show                         Ganglands  Julien Leclercq
# 2       6  TV Show                     Midnight Mass    Mike Flanagan
# 3      14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4       8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
type(df['Show_id'][0])
# Out:
# str

# %%
df['Show_id']=df['Show_id'].astype(int)

# %%
df['Show_id']
# Out:
# 0          1
# 1          3
# 2          6
# 3         14
# 4          8
#         ...
# 8785    8797
# 8786    8798
# 8787    8801
# 8788    8784
# 8789    8786
# Name: Show_id, Length: 8790, dtype: int64

# %%
df.head()
# Out:
#    Show_id     Type                             Title         Director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       8790 non-null   int64
#  1   Type          8790 non-null   object
#  2   Title         8790 non-null   object
#  3   Director      8790 non-null   object
#  4   Country       8790 non-null   object
#  5   Date_added    8790 non-null   object
#  6   Release_year  8790 non-null   int64
#  7   Duration      8790 non-null   object
#  8   Listed_in     8790 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 618.2+ KB

# %%
df['Date_added'].apply(lambda x:x.replace('/','-'))
# Out:
# 0        9-25-2021
# 1        9-24-2021
# 2        9-24-2021
# 3        9-22-2021
# 4        9-24-2021
#            ...
# 8785     1-17-2017
# 8786     9-13-2018
# 8787    12-15-2016
# 8788     6-23-2018
# 8789      6-7-2018
# Name: Date_added, Length: 8790, dtype: object

# %%
df['Date_added']=pd.to_datetime(df['Date_added'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       8790 non-null   int64
#  1   Type          8790 non-null   object
#  2   Title         8790 non-null   object
#  3   Director      8790 non-null   object
#  4   Country       8790 non-null   object
#  5   Date_added    8790 non-null   datetime64[ns]
#  6   Release_year  8790 non-null   int64
#  7   Duration      8790 non-null   object
#  8   Listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 618.2+ KB

# %%
df['Release_year']=df['Release_year'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       8790 non-null   int64
#  1   Type          8790 non-null   object
#  2   Title         8790 non-null   object
#  3   Director      8790 non-null   object
#  4   Country       8790 non-null   object
#  5   Date_added    8790 non-null   datetime64[ns]
#  6   Release_year  8790 non-null   int64
#  7   Duration      8790 non-null   object
#  8   Listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 618.2+ KB

# %%
data=df['Country'].value_counts().reset_index()
data[data['Country']=='India']
# Out:
#   Country  count
# 1   India   1057

# %%
df
# Out:
#       Show_id     Type                             Title         Director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             Country Date_added  Release_year   Duration  \
# 0     United States 2021-09-25          2020     90 min
# 1            France 2021-09-24          2021   1 Season
# 2     United States 2021-09-24          2021   1 Season
# 3            Brazil 2021-09-22          2021     91 min
# 4     United States 2021-09-24          1993    125 min
# ...             ...        ...           ...        ...
# 8785         Turkey 2017-01-17          2016  2 Seasons
# 8786  United States 2018-09-13          2016  3 Seasons
# 8787       Pakistan 2016-12-15          2012   1 Season
# 8788       Pakistan 2018-06-23          2016   1 Season
# 8789       Pakistan 2018-06-07          2016   1 Season
#
#                                               Listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 9 columns]

# %%
df.to_csv('cleaned_netflix-data.csv',index=False)
